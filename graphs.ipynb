# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

floor = pd.read_csv("libFloor.csv")

# %%
quarters = floor['Quarter'].unique().tolist()
# quarters.remove()
print(quarters)
# Out:
# ['Fall 2021', nan, 'Winter 2022', 'Spring 2022', 'Summer 2022', 'Fall 2022', 'Winter 2023', 'Spring 2023']

# %%
new_floor = floor[~(floor['Location'] == 'UCSB Library')]

new_floor['Timestamp'] = pd.to_datetime(new_floor['Timestamp'])

def shorten(timestamp):
    return timestamp.strftime("%Y-%m-%d")

new_floor['Timestamp'] = new_floor['Timestamp'].apply(shorten)
new_floor.head()
# new_floor_f21 = new_floor[new_floor['Quarter'] == 'Fall 2021']
# Out:
# /var/folders/5_/dpt6cl3j4fs4w5184wqyd8_r0000gn/T/ipykernel_28949/742615936.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_floor['Timestamp'] = pd.to_datetime(new_floor['Timestamp'])
# /var/folders/5_/dpt6cl3j4fs4w5184wqyd8_r0000gn/T/ipykernel_28949/742615936.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_floor['Timestamp'] = new_floor['Timestamp'].apply(shorten)
#              Location   Timestamp  Average Occupancy  Peak Occupancy  \
# ...

# %%
def floor_chart(qtr):
    sns.set_style('darkgrid')
    sns.set(rc={'figure.figsize':(14,8)})

    floor_qtr = new_floor[new_floor['Quarter'] == qtr]
    ax = sns.lineplot(data=floor_qtr, x ='Timestamp', y = 'Average Occupancy',
                        hue='Location', palette='viridis',
                        legend='full', lw=2, ci=None)

    # reassign/group tick labels 
    # stagger or spread out date time ticks 
    ax.xaxis.set_major_locator(ticker.MultipleLocator(8))
    plt.legend(bbox_to_anchor=(1, 1))
    plt.ylabel('Average Occupancy')
    plt.xlabel('Timestamp')
    plt.title(qtr)

    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    plt.show()

# %% [markdown]
# https://towardsdatascience.com/8-visualizations-with-python-to-handle-multiple-time-series-data-19b5b2e66dd0

# %%
for qtr in quarters: 
    floor_chart(qtr)
# look into order reversal errors
# Out:
# /var/folders/5_/dpt6cl3j4fs4w5184wqyd8_r0000gn/T/ipykernel_28949/2957026044.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.lineplot(data=floor_qtr, x ='Timestamp', y = 'Average Occupancy',
# /var/folders/5_/dpt6cl3j4fs4w5184wqyd8_r0000gn/T/ipykernel_28949/2957026044.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# /var/folders/5_/dpt6cl3j4fs4w5184wqyd8_r0000gn/T/ipykernel_28949/2957026044.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.lineplot(data=floor_qtr, x ='Timestamp', y = 'Average Occupancy',
# /var/folders/5_/dpt6cl3j4fs4w5184wqyd8_r0000gn/T/ipykernel_28949/2957026044.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.lineplot(data=floor_qtr, x ='Timestamp', y = 'Average Occupancy',
# ...

# %%
# alter timestamps 
# make interactive

# %% [markdown]
# ## Total Occupants by quarter
# data courtesy of BOPS

# %%
d = {'Fall':[855539,811983,861807,859829,257,653655,668676], 
    'Winter':[755598,801348,854998,682275,241,324574,706988],
    'Spring': [768324,785782,820736,0,8082,598260,627746],
    'Summer':[262421,217676,248824,0,8528,194910,51835]}
qt = pd.DataFrame(data=d)
qt['Total']=qt.sum(axis=1)
qt.index=['2016-2017', '2017-2018', '2018-2019', '2019-2020','2020-2021','2021-2022','2022-2023']
qt
# Out:
#              Fall  Winter  Spring  Summer    Total
# 2016-2017  855539  755598  768324  262421  2641882
# 2017-2018  811983  801348  785782  217676  2616789
# 2018-2019  861807  854998  820736  248824  2786365
# 2019-2020  859829  682275       0       0  1542104
# 2020-2021     257     241    8082    8528    17108
# 2021-2022  653655  324574  598260  194910  1771399
# 2022-2023  668676  706988  627746   51835  2055245

# %%
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# fig = go.Figure()
# fig.add_trace(go.Histogram(qt,x='Fall'))
# fig.add_trace(go.Histogram(qt,x='Winter'))
#fig.add_trace(go.Histogram(qt,x='Spring'))
# fig.add_trace(go.Histogram(qt,x='Summer'))

colors = px.colors.qualitative.T10

# plotly
fig = px.bar(qt, 
             x = qt.index,
             y = [c for c in qt.columns],
             template = 'seaborn',
             color_discrete_sequence = colors,
             # xaxis = 'Total Occupants',
             # index = 'School Year'
             title = 'Yearly Library Occupancy Totals by Year and Quarter', 
             )

fig.show()
